# %% [markdown]
# # Getting the Data form every Constituent Assembly

# %%
import pandas as pd

# %%
constituency_1 = [
    {"name": "Prakashman Singh", "party": "Nepali Congress", "votes": 7143, "constituency": 1},
    {"name": "Rabindra Mishra", "party": "Rastriya Prajatantra Party", "votes": 7018, "constituency": 1},
    {"name": "Pukar Bam", "party": "Rastriya Swatantra Party", "votes": 4115, "constituency": 1},
    {"name": "Kiran Poudel", "party": "CPN UML", "votes": 3532, "constituency": 1},
    {"name": "Ramesh Prasad Kharel", "party": "Nepal Sushashan Party Nepal", "votes": 3124, "constituency": 1},
    {"name": "Balkrishna Neupane", "party": "Nepalka Lagi Nepali Party", "votes": 590, "constituency": 1},
    {"name": "Dambar Shahu", "party": "Hamro Nepali Party", "votes": 150, "constituency": 1},
    {"name": "Surendra Prasad Dhakal", "party": "CPN Maxist Leninist", "votes": 92, "constituency": 1},
    {"name": "Risham Bhattarai", "party": "Nepali Congress (BP)", "votes": 76, "constituency": 1},
    {"name": "Hari Sharan Shrestha", "party": "Nepal Workers and Peasants Party", "votes": 50, "constituency": 1},
    {"name": "Sangita Bogati", "party": "Independent", "votes": 36, "constituency": 1},
    {"name": "Shankar Banjade", "party": "Bibeksheel Sajha Party", "votes": 30, "constituency": 1},
    {"name": "Prakash Shrestha", "party": "Maulik Jarokilo Party", "votes": 23, "constituency": 1},
    {"name": "Prakash Nayaju", "party": "Loktantrik Samajwadi Party", "votes": 22, "constituency": 1},
    {"name": "Harendra Choudhary", "party": "Janamat Party", "votes": 22, "constituency": 1},
    {"name": "Kul Bahadur Tamang", "party": "Independent", "votes": 20, "constituency": 1},
    {"name": "Kiran Kumar Sharma Paudel", "party": "Nepalwad", "votes": 19, "constituency": 1},
    {"name": "Indra Bahadur Thapa", "party": "Nationalist Peoples Party", "votes": 18, "constituency": 1},
    {"name": "Shanti Devi KC", "party": "Rastriya Prajatantra Party Nepal", "votes": 17, "constituency": 1},
    {"name": "Man Bahadur Rai", "party": "Rastriya Janamukti Party", "votes": 16, "constituency": 1},
    {"name": "Goma Khatiwada Adhikari", "party": "Independent", "votes": 12, "constituency": 1},
    {"name": "Manita Shrestha", "party": "Janasamajwadi Party Nepal", "votes": 8, "constituency": 1},
    {"name": "Hari Kumar Ghale", "party": "Aamul Pariwartan Mashika Party", "votes": 7, "constituency": 1},
    {"name": "Manju Rana Magar", "party": "Sanghiya Loktantrik Rastriya Manch", "votes": 6, "constituency": 1},
    {"name": "Sunita Basel", "party": "Independent", "votes": 5, "constituency": 1},
    {"name": "Meera Bista", "party": "Independent", "votes": 3, "constituency": 1},
    {"name": "Dev Sharma", "party": "Independent", "votes": 3, "constituency": 1},
    {"name": "Sita Tamang KC", "party": "Independent", "votes": 3, "constituency": 1},
    {"name": "Nirjal Shah", "party": "Independent", "votes": 2, "constituency": 1},
    {"name": "Sangita Rajbahak", "party": "Independent", "votes": 2, "constituency": 1},
    {"name": "Khumkala Lamichhane", "party": "Independent", "votes": 1, "constituency": 1},
    {"name": "Durga Prasad Limbu", "party": "Independent", "votes": 1, "constituency": 1}
]

# %%
constituency_2 = [
    {"name": "Sobita Gautam", "party": "Rastriya Swatantra Party", "votes": 15229, "constituency": 2},
    {"name": "Maniram Phuyal", "party": "CPN UML", "votes": 11555, "constituency": 2},
    {"name": "Kanti Devi Pokharel", "party": "Rastriya Prajatantra Party", "votes": 11014, "constituency": 2},
    {"name": "Onsari Gharti", "party": "CPN Maoist", "votes": 9449, "constituency": 2},
    {"name": "Punya Prasad Prasai", "party": "Sachet Nepali Party", "votes": 441, "constituency": 2},
    {"name": "Koshraj Subedi", "party": "Hamro Nepali Party", "votes": 254, "constituency": 2},
    {"name": "Dhanesh Thapa", "party": "Bibeksheel Sajha Party", "votes": 161, "constituency": 2},
    {"name": "Kashiraj Pudasaini", "party": "Independent", "votes": 120, "constituency": 2},
    {"name": "Anup Bahadur", "party": "Independent", "votes": 119, "constituency": 2},
    {"name": "Krishnaram Puri", "party": "Independent", "votes": 93, "constituency": 2},
    {"name": "Ganesh Prasad Pudasaini", "party": "Janamat Party", "votes": 88, "constituency": 2},
    {"name": "Anil Shrestha", "party": "Nepal Workers and Peasants Party", "votes": 81, "constituency": 2},
    {"name": "Gopal Bahadur Tandukar", "party": "Janata Samajwadi Party", "votes": 52, "constituency": 2},
    {"name": "Prakash Adhikari", "party": "Independent", "votes": 50, "constituency": 2},
    {"name": "Bijendra Basnet", "party": "Punarjagaran Party Nepal", "votes": 40, "constituency": 2},
    {"name": "Ram Madi Nepal", "party": "Nepalka Lagi Nepali Party", "votes": 26, "constituency": 2},
    {"name": "Manusudhan Pudasaini", "party": "Loktantrik Samajwadi Party", "votes": 25, "constituency": 2},
    {"name": "Ishwor Gatuam", "party": "Nepalwad", "votes": 20, "constituency": 2},
    {"name": "Mahesh Bastola", "party": "Rastriya Prajatantra Party Nepal", "votes": 18, "constituency": 2},
    {"name": "Balram Chaulagai", "party": "Independent", "votes": 16, "constituency": 2},
    {"name": "Hem Bikram Silwal", "party": "Nepali Congress (BP)", "votes": 15, "constituency": 2},
    {"name": "Sita Tamang", "party": "Mangol National Organization", "votes": 14, "constituency": 2},
    {"name": "Laxman Pokherel", "party": "Maulik Jarokilo Party", "votes": 13, "constituency": 2},
    {"name": "Chiranjivi Rai", "party": "Rastriya Janamukti Party", "votes": 13, "constituency": 2},
    {"name": "Bhagwati Dhakal", "party": "Independent", "votes": 7, "constituency": 2},
    {"name": "Binod Prasad Ghimere", "party": "Independent", "votes": 6, "constituency": 2},
    {"name": "Dinesh Khadka", "party": "Independent", "votes": 6, "constituency": 2},
    {"name": "Bidur Prasad Simkhada", "party": "Gandhiwadi Party Nepal", "votes": 3, "constituency": 2},
    {"name": "Prakash Adhikari", "party": "Independent", "votes": 3, "constituency": 2},
    {"name": "Krishna Adhikari", "party": "Independent", "votes": 2, "constituency": 2}
]

# %%
constituency_3 = [
    {"name": "Santosh Chalise", "party": "Nepali Congress", "votes": 15158, "constituency": 3},
    {"name": "Krishna Bahadur Rai", "party": "CPN UML", "votes": 11196, "constituency": 3},
    {"name": "Durga Bikram Thapa Chettri", "party": "Rastriya Swatantra Party", "votes": 5865, "constituency": 3},
    {"name": "Ganesh Giri", "party": "Rastriya Prajatantra Party", "votes": 2511, "constituency": 3},
    {"name": "Niranjan Pudasaini", "party": "Independent", "votes": 605, "constituency": 3},
    {"name": "Dwarika Adhikari", "party": "Hamro Nepali Party", "votes": 547, "constituency": 3},
    {"name": "Badri Prasad Bhajgai", "party": "CPN Maoist", "votes": 518, "constituency": 3},
    {"name": "Dinesh Khanal", "party": "Independent", "votes": 261, "constituency": 3},
    {"name": "Shree Krishna Jyoti", "party": "Independent", "votes": 148, "constituency": 3},
    {"name": "Rajesh Bista", "party": "Independent", "votes": 97, "constituency": 3},
    {"name": "Bisok Dangol", "party": "Nepal Workers and Peasants Party", "votes": 87, "constituency": 3},
    {"name": "Krishna Kaji Shrestha", "party": "Mangol National Organization", "votes": 67, "constituency": 3},
    {"name": "Netra Bahadur Tamang", "party": "Aamul Pariwartan Mashika Party", "votes": 51, "constituency": 3},
    {"name": "Mohan Kumar Bishwakarma", "party": "Janata Samajwadi Party", "votes": 44, "constituency": 3},
    {"name": "Kedar Nath Mishra", "party": "Independent", "votes": 36, "constituency": 3},
    {"name": "Govinda Nepal", "party": "Janamat Party", "votes": 34, "constituency": 3},
    {"name": "Savina Neupane", "party": "Maulik Jarokilo Party", "votes": 30, "constituency": 3},
    {"name": "Jagganath Devkota", "party": "Independent", "votes": 17, "constituency": 3},
    {"name": "Nurpu Genjen Sherpa", "party": "Sanghiya Loktantrik Rastriya Manch", "votes": 11, "constituency": 3},
    {"name": "Rakhsha Kumar Rai", "party": "Samajik Loktantrik Party", "votes": 11, "constituency": 3},
    {"name": "Mohan Bahadur Basnet", "party": "Loktantrik Samajwadi Party", "votes": 9, "constituency": 3},
    {"name": "Kabita Bista Sunar", "party": "Independent", "votes": 8, "constituency": 3},
    {"name": "Bindu Magar", "party": "Independent", "votes": 8, "constituency": 3}
]

# %%
constituency_4 = [
    {"name": "Gagan Kumar Thapa", "party": "Nepali Congress", "votes": 21302, "constituency": 4},
    {"name": "Rajan Bhattarai", "party": "CPN UML", "votes": 13855, "constituency": 4},
    {"name": "Dr. Thakur Mohan Shrestha", "party": "Rastriya Prajatantra Party", "votes": 4050, "constituency": 4},
    {"name": "Arjun Kumar Prasad", "party": "Independent", "votes": 2308, "constituency": 4},
    {"name": "Archana Shemsher Rana", "party": "Hamro Nepali Party", "votes": 1294, "constituency": 4},
    {"name": "Sibendra K.C", "party": "Independent", "votes": 231, "constituency": 4},
    {"name": "Kaji Bahadur Karki", "party": "Independent", "votes": 151, "constituency": 4},
    {"name": "Ramesh Dangol", "party": "Nepal Workers and Peasants Party", "votes": 151, "constituency": 4},
    {"name": "Hem Bahadur Bomjan", "party": "Independent", "votes": 116, "constituency": 4},
    {"name": "Rudra Prasad Poudel", "party": "Independent", "votes": 73, "constituency": 4},
    {"name": "Shyam Babu Gautam", "party": "Punarjagaran Party Nepal", "votes": 73, "constituency": 4},
    {"name": "Krishna Kumar Tamang", "party": "Independent", "votes": 56, "constituency": 4},
    {"name": "Lila Maya Poudel", "party": "CPN Maxist Leninist", "votes": 41, "constituency": 4},
    {"name": "Navaraj Bhandari", "party": "Ekikrit Shakti Nepal", "votes": 40, "constituency": 4},
    {"name": "Numnath Pyakurel", "party": "Maulik Jarokilo Party", "votes": 36, "constituency": 4},
    {"name": "Dhurba Raj Giri", "party": "Aamul Pariwartan Mashika Party", "votes": 30, "constituency": 4},
    {"name": "Chet Bahadur Aale", "party": "Rastriya Janamukti Party", "votes": 28, "constituency": 4},
    {"name": "Dipak Kumar Pokheral", "party": "Nepalka lagi Nepali Party", "votes": 26, "constituency": 4},
    {"name": "Laal Kumar Thapa Rana", "party": "Mangol National Organization", "votes": 26, "constituency": 4},
    {"name": "Rajesh Bharati", "party": "Miteri Party Nepal", "votes": 22, "constituency": 4},
    {"name": "Pikesh Pariyar", "party": "Sanghiya Loktantrik Rastriya Manch", "votes": 21, "constituency": 4},
    {"name": "Tharka Bahadur Basnet", "party": "Independent", "votes": 18, "constituency": 4},
    {"name": "Roshan Barma", "party": "Independent", "votes": 14, "constituency": 4},
    {"name": "Shyam Raj Bhetwal", "party": "Independent", "votes": 14, "constituency": 4},
    {"name": "Bhanu Kumar Khadka", "party": "Loktantrik Samajwadi Party", "votes": 13, "constituency": 4},
    {"name": "Navaraj Thapa", "party": "Independent", "votes": 7, "constituency": 4},
    {"name": "Dinesh Chaulagai", "party": "Independent", "votes": 6, "constituency": 4},
    {"name": "Rohit Dangol", "party": "Independent", "votes": 3, "constituency": 4},
    {"name": "Rabindra Dev Dhakal", "party": "Independent", "votes": 2, "constituency": 4},
    {"name": "Maheshwor K.C", "party": "Independent", "votes": 1, "constituency": 4},
    {"name": "Khur Hari Pudasaini", "party": "Janasamajwadi Party Nepal", "votes": 0, "constituency": 4}
]

# %%
constituency_5 = [
    {"name": "Pradip Poudel", "party": "Nepali Congress", "votes": 15237, "constituency": 5},
    {"name": "Ishwor Pokhrel", "party": "CPN UML", "votes": 10175, "constituency": 5},
    {"name": "Dr.Pranaya Shemser Rana", "party": "Rastriya Swatantra Party", "votes": 5473, "constituency": 5},
    {"name": "Ram Prasad Upreti", "party": "Rastriya Prajatantra Party", "votes": 3155, "constituency": 5},
    {"name": "Shree Ram Gurung", "party": "Independent", "votes": 2761, "constituency": 5},
    {"name": "Hemraj Thapa", "party": "Independent", "votes": 2440, "constituency": 5},
    {"name": "Sushant Shrestha", "party": "Independent", "votes": 1711, "constituency": 5},
    {"name": "Sailesh Dandol", "party": "Nepal Workers and Peasants Party", "votes": 1122, "constituency": 5},
    {"name": "Ranju Neupane", "party": "Independent", "votes": 600, "constituency": 5},
    {"name": "Madhu Sudhan Pathak", "party": "Hamro Nepali Party", "votes": 364, "constituency": 5},
    {"name": "Ramesh K.C", "party": "Independent", "votes": 216, "constituency": 5},
    {"name": "Bijaya Kandel", "party": "Independent", "votes": 167, "constituency": 5},
    {"name": "Bhim Bahadur Magar", "party": "Janata Samajwadi Party", "votes": 131, "constituency": 5},
    {"name": "Sagar Khadka", "party": "Nepalka lagi Nepali Party", "votes": 110, "constituency": 5},
    {"name": "Gopilal Neupane", "party": "Independent", "votes": 93, "constituency": 5},
    {"name": "Tik Maya Gurung", "party": "Nepal Communist Party Maxist (Puspalal)", "votes": 84, "constituency": 5},
    {"name": "Shailendra Basnet", "party": "Independent", "votes": 82, "constituency": 5},
    {"name": "Dipak Kumar Sharma", "party": "Nepalwad", "votes": 68, "constituency": 5},
    {"name": "Raju Bista", "party": "Janasamajwadi Party Nepal", "votes": 48, "constituency": 5},
    {"name": "Dipak Singh", "party": "Ekikrit Shakti Nepal", "votes": 39, "constituency": 5},
    {"name": "Ram Krishna Pariyar", "party": "Maulik Jarokilo Party", "votes": 38, "constituency": 5},
    {"name": "Danindra Joshi", "party": "Loktantrik Samajwadi Party", "votes": 37, "constituency": 5},
    {"name": "Lovely Thapa", "party": "Nationalist Peoples Party", "votes": 29, "constituency": 5},
    {"name": "Binita Aryal", "party": "Independent", "votes": 24, "constituency": 5},
    {"name": "Santiram Pandey", "party": "Independent", "votes": 20, "constituency": 5},
    {"name": "Babu Ram Pokheral", "party": "Independent", "votes": 12, "constituency": 5},
    {"name": "Kumar Koirala", "party": "Independent", "votes": 5, "constituency": 5},
    {"name": "Krishna Raj Shrestha", "party": "Independent", "votes": 4, "constituency": 5},
    {"name": "Narayan Prasad Dahal", "party": "Independent", "votes": 4, "constituency": 5}
]

# %%
constituency_6 = [
    {"name": "Shishir Khanal", "party": "Rastriya Swatantra Party", "votes": 14204, "constituency": 6},
    {"name": "Shabendra Khanal", "party": "CPN UML", "votes": 8911, "constituency": 6},
    {"name": "Bhemsen Das Pradhan", "party": "Nepali Congress", "votes": 8805, "constituency": 6},
    {"name": "Bishnu Prasad Acharya", "party": "Rastriya Prajatantra Party", "votes": 2185, "constituency": 6},
    {"name": "Sanjay Man Shrestha", "party": "Independent", "votes": 577, "constituency": 6},
    {"name": "Sanak Man Maharjan", "party": "Nepal Workers and Peasants Party", "votes": 575, "constituency": 6},
    {"name": "Mukunda Silwal", "party": "Hamro Nepali Party", "votes": 544, "constituency": 6},
    {"name": "Premasagar Karmacharya", "party": "Independent", "votes": 517, "constituency": 6},
    {"name": "Manoj Acharya", "party": "Janata Samajwadi Party", "votes": 183, "constituency": 6},
    {"name": "Mahehwor Karki", "party": "Rastriya Prajatantra Party Nepal", "votes": 149, "constituency": 6},
    {"name": "Nirdesh Silwal", "party": "Independent", "votes": 127, "constituency": 6},
    {"name": "Dipu Upreti", "party": "Independent", "votes": 123, "constituency": 6},
    {"name": "Bal Bahadur K.C", "party": "Independent", "votes": 111, "constituency": 6},
    {"name": "Rajendra Khanal", "party": "Nepal Aama Party", "votes": 67, "constituency": 6},
    {"name": "Ajit Khadka", "party": "Bibeksheel Sajha Party", "votes": 63, "constituency": 6},
    {"name": "Tara Rasayili", "party": "Rastriya Janamukti Party", "votes": 41, "constituency": 6},
    {"name": "Kamal Neupane", "party": "Maulik Jarokilo Party", "votes": 35, "constituency": 6},
    {"name": "Bishnu Prasad Dhakal", "party": "Independent", "votes": 33, "constituency": 6},
    {"name": "Kaji Karki", "party": "Ekikrit Shakti Nepal", "votes": 31, "constituency": 6},
    {"name": "Khagendra Dhakal", "party": "Independent", "votes": 18, "constituency": 6},
    {"name": "Sanu Kancha Maharjan", "party": "Independent", "votes": 15, "constituency": 6},
    {"name": "Mahesh Shrestha (Maskey)", "party": "Independent", "votes": 14, "constituency": 6},
    {"name": "Kiran Ingnam", "party": "Independent", "votes": 12, "constituency": 6},
    {"name": "Janak Raj Thapaliya", "party": "Independent", "votes": 3, "constituency": 6}
]

# %%
constituency_7 = [
    {"name": "Ganesh Parajuli", "party": "Rastriya Swatantra Party", "votes": 8743, "constituency": 7},
    {"name": "Shyam Kumar Ghimire", "party": "CPN UML", "votes": 6800, "constituency": 7},
    {"name": "Ashmita Singh (Manusi) Yami Bhattarai", "party": "CPN Maoist", "votes": 6063, "constituency": 7},
    {"name": "Dhub Bikram Malla", "party": "Rastriya Prajatantra Party", "votes": 2863, "constituency": 7},
    {"name": "Yadvya Lal Kayasya", "party": "Independent", "votes": 2782, "constituency": 7},
    {"name": "Rajendra Prasad Shrestha", "party": "Janata Samajwadi Party", "votes": 2461, "constituency": 7},
    {"name": "Kiran K.C", "party": "Independent", "votes": 1570, "constituency": 7},
    {"name": "Prabendra Pokheral", "party": "Hamro Nepali Party", "votes": 1510, "constituency": 7},
    {"name": "Ram Bir Manandar", "party": "Independent", "votes": 1215, "constituency": 7},
    {"name": "Rabindra Kumar Shrestha", "party": "Independent", "votes": 828, "constituency": 7},
    {"name": "Kiran Maharjan", "party": "Nepal Workers and Peasants Party", "votes": 248, "constituency": 7},
    {"name": "Juju Kaji Maharjan", "party": "Rastriya Janamukti Party", "votes": 211, "constituency": 7},
    {"name": "Ram Nepali", "party": "Nepalka lagi Nepali Party", "votes": 115, "constituency": 7},
    {"name": "Prasanna Kumar Aryal", "party": "Independent", "votes": 107, "constituency": 7},
    {"name": "Ishwor Aryal", "party": "Independent", "votes": 102, "constituency": 7},
    {"name": "Kumar Khaki Shrestha", "party": "Rastriya Prajatantra Party Nepal", "votes": 92, "constituency": 7},
    {"name": "Krishna Prasad Dawadi", "party": "Nepal Aama Party", "votes": 77, "constituency": 7},
    {"name": "Sujan Ratna Bajracharya", "party": "Independent", "votes": 75, "constituency": 7},
    {"name": "Lok Prasad Simkhada", "party": "Independent", "votes": 38, "constituency": 7},
    {"name": "Hem Bahadur Dangol", "party": "Independent", "votes": 33, "constituency": 7},
    {"name": "Kamala Bhusal", "party": "Nepali Congress (BP)", "votes": 31, "constituency": 7},
    {"name": "Shailendra Raj Shrestha", "party": "Janasamajwadi Party Nepal", "votes": 28, "constituency": 7},
    {"name": "Prakash Kunwar", "party": "Independent", "votes": 28, "constituency": 7},
    {"name": "Bharat Tamang", "party": "Independent", "votes": 13, "constituency": 7},
    {"name": "Manju Maya Tamang", "party": "Independent", "votes": 8, "constituency": 7},
    {"name": "Januka Poudel", "party": "Independent", "votes": 7, "constituency": 7},
    {"name": "Laxman Prasad Gajurel", "party": "Independent", "votes": 6, "constituency": 7},
    {"name": "Rojina Awale", "party": "Independent", "votes": 4, "constituency": 7},
    {"name": "Raj Kumar Koirala", "party": "Independent", "votes": 3, "constituency": 7}
]

# %%
constituency_8 = [
    {"name": "Biraj Bhakta Shrestha", "party": "Rastriya Swatantra Party", "votes": 10105, "constituency": 8},
    {"name": "Suman Sayami", "party": "Hamro Nepali Party", "votes": 5889, "constituency": 8},
    {"name": "Jeewan Ram Shrestha", "party": "CPN (Unified Socialist)", "votes": 4877, "constituency": 8},
    {"name": "Prakash Rimal", "party": "Rastriya Prajatantra Party", "votes": 4225, "constituency": 8},
    {"name": "Shiv Sundar Rajabhaidha", "party": "CPN UML", "votes": 3522, "constituency": 8},
    {"name": "Manoj Kumar Khadka", "party": "Janata Samajwadi Party", "votes": 360, "constituency": 8},
    {"name": "Krishna Maya Manandar", "party": "Nepal Workers and Peasants Party", "votes": 194, "constituency": 8},
    {"name": "Rajendra Thapa", "party": "Rastriya Prajatantra Party Nepal", "votes": 89, "constituency": 8},
    {"name": "Santa Bahadur Shakya", "party": "Janamat Party", "votes": 76, "constituency": 8},
    {"name": "Dipak Prasad Khanal", "party": "Independent", "votes": 51, "constituency": 8},
    {"name": "Suman Kumar Balami", "party": "Sachet Nepali Party", "votes": 40, "constituency": 8},
    {"name": "Ramesh Kumar Dangol", "party": "Rastriya Janamukti Party", "votes": 39, "constituency": 8},
    {"name": "Chatra Kumar Pakahin", "party": "Aamul Pariwartan Mashika Party", "votes": 35, "constituency": 8},
    {"name": "Santosh Deula", "party": "Loktantrik Samajwadi Party", "votes": 30, "constituency": 8},
    {"name": "Durga Devi Maharjan", "party": "Independent", "votes": 24, "constituency": 8},
    {"name": "Resham Bahadur Sunar", "party": "Nepali Janata Dal", "votes": 22, "constituency": 8},
    {"name": "Rekh Kumar Gurung", "party": "Janata Pragatisheel Party", "votes": 16, "constituency": 8},
    {"name": "Hemraj Baral", "party": "Independent", "votes": 11, "constituency": 8},
    {"name": "Bijaya Dangol", "party": "Nepal Sanghiya Samajwadi Party", "votes": 10, "constituency": 8}
]

# %%
constituency_9 = [
    {"name": "Krishna Gopal Shrestha", "party": "CPN UML", "votes": 11956, "constituency": 9},
    {"name": "Tek Bahadur Pokheral", "party": "Rastriya Swatantra Party", "votes": 10961, "constituency": 9},
    {"name": "Kalpana Dhamal", "party": "CPN Maoist", "votes": 6402, "constituency": 9},
    {"name": "Devendra Pradhan", "party": "Rastriya Prajatantra Party", "votes": 4785, "constituency": 9},
    {"name": "Milan Pandey", "party": "Sajha Party Nepal", "votes": 2327, "constituency": 9},
    {"name": "Iresh Shrestha", "party": "Hamro Nepali Party", "votes": 1586, "constituency": 9},
    {"name": "Suman Maharjan", "party": "Nepal Workers and Peasants Party", "votes": 1552, "constituency": 9},
    {"name": "Sunil Rijal", "party": "Independent", "votes": 833, "constituency": 9},
    {"name": "Sharmila Suwal (Dangol)", "party": "Janata Samajwadi Party", "votes": 792, "constituency": 9},
    {"name": "Dr. Gyan Bahadur Basnet", "party": "Independent", "votes": 314, "constituency": 9},
    {"name": "Ramesh Thapa", "party": "Nepali Congress (BP)", "votes": 247, "constituency": 9},
    {"name": "Bhai Raja Bhandari", "party": "Independent", "votes": 151, "constituency": 9},
    {"name": "Ujala Sthapit", "party": "Rastriya Janamukti Party", "votes": 123, "constituency": 9},
    {"name": "Rajendra Prasad Pathak", "party": "Independent", "votes": 94, "constituency": 9},
    {"name": "Uddav Rokka", "party": "Independent", "votes": 82, "constituency": 9},
    {"name": "Prajul Joshi", "party": "Loktantrik Samajwadi Party", "votes": 81, "constituency": 9},
    {"name": "Laxman Singh Khadka", "party": "Independent", "votes": 64, "constituency": 9},
    {"name": "Rachana Shrestha", "party": "Independent", "votes": 60, "constituency": 9},
    {"name": "Ganesh Thapa", "party": "Independent", "votes": 31, "constituency": 9},
    {"name": "Ram Kumar Rijal", "party": "Independent", "votes": 31, "constituency": 9},
    {"name": "Ambika Thapa", "party": "Maulik Jarokilo Party", "votes": 23, "constituency": 9},
    {"name": "Madhu Karki", "party": "Independent", "votes": 22, "constituency": 9}
]

# %%
constituency_10 = [
    {"name": "Rajendra Kumar K.C", "party": "Nepali Congress", "votes": 14448, "constituency": 10},
    {"name": "Himesh K.c", "party": "CPN UML", "votes": 11786, "constituency": 10},
    {"name": "Pradip Bista", "party": "Rastriya Swatantra Party", "votes": 7347, "constituency": 10},
    {"name": "Bal Ram Thapa", "party": "Rastriya Prajatantra Party", "votes": 6277, "constituency": 10},
    {"name": "Anjana Bisankhe", "party": "CPN Maoist", "votes": 4260, "constituency": 10},
    {"name": "Narayan Maharjan", "party": "Nepal Workers and Peasants Party", "votes": 1776, "constituency": 10},
    {"name": "Indra Bahadur Baral", "party": "Hamro Nepali Party", "votes": 234, "constituency": 10},
    {"name": "Srijana Bartaula", "party": "Maulik Jarokilo Party", "votes": 0, "constituency": 10},
    {"name": "Kumar Lama", "party": "Nagarik Unmukti Party", "votes": 0, "constituency": 10},
    {"name": "Purna Lal Shrestha", "party": "Rastriya Prajatantra Party Nepal", "votes": 0, "constituency": 10},
    {"name": "Dhan Keshar Suryabanshi", "party": "Rastriya Janamukti Party", "votes": 0, "constituency": 10},
    {"name": "Santa Prasad Shrestha", "party": "Nepali Congress (BP)", "votes": 0, "constituency": 10},
    {"name": "Sanan Shrestha", "party": "Bibeksheel Sajha Party", "votes": 0, "constituency": 10},
    {"name": "Chet Bahadur Muktana", "party": "Aamul Pariwartan Mashika Party", "votes": 0, "constituency": 10},
    {"name": "Ganga Prasad Bhetal", "party": "Nepal Aama Party", "votes": 0, "constituency": 10},
    {"name": "Ram Kumar Thapa", "party": "Independent", "votes": 0, "constituency": 10},
    {"name": "Rambabu Thakur", "party": "Independent", "votes": 0, "constituency": 10},
    {"name": "Tilak Bahadur Rijal", "party": "Independent", "votes": 0, "constituency": 10}
]

# %%
# Changing each of the Data Dictionary into Panda Daframe
df_1 = pd.DataFrame(constituency_1)
df_2 = pd.DataFrame(constituency_2)
df_3 = pd.DataFrame(constituency_3)
df_4 = pd.DataFrame(constituency_4)
df_5 = pd.DataFrame(constituency_5)
df_6 = pd.DataFrame(constituency_6)
df_7 = pd.DataFrame(constituency_7)
df_8 = pd.DataFrame(constituency_8)
df_9 = pd.DataFrame(constituency_9)
df_10 = pd.DataFrame(constituency_10)

# %%
print(f"Total of {df_1.shape[0]} candidates Participated in Constituency 1")
print(f"Total of {df_2.shape[0]} candidates Participated in Constituency 2")
print(f"Total of {df_3.shape[0]} candidates Participated in Constituency 3")
print(f"Total of {df_4.shape[0]} candidates Participated in Constituency 4")
print(f"Total of {df_5.shape[0]} candidates Participated in Constituency 5")
print(f"Total of {df_6.shape[0]} candidates Participated in Constituency 6")
print(f"Total of {df_7.shape[0]} candidates Participated in Constituency 7")
print(f"Total of {df_8.shape[0]} candidates Participated in Constituency 8")
print(f"Total of {df_9.shape[0]} candidates Participated in Constituency 9")
print(f"Total of {df_10.shape[0]} candidates Participated in Constituency 10")
# Out:
# Total of 32 candidates Participated in Constituency 1
# Total of 30 candidates Participated in Constituency 2
# Total of 23 candidates Participated in Constituency 3
# Total of 31 candidates Participated in Constituency 4
# Total of 29 candidates Participated in Constituency 5
# Total of 24 candidates Participated in Constituency 6
# Total of 29 candidates Participated in Constituency 7
# Total of 19 candidates Participated in Constituency 8
# Total of 22 candidates Participated in Constituency 9
# Total of 18 candidates Participated in Constituency 10

# %%
# Doing the same thing using loop
# Put your dataframes in a list in order
dfs = [df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10]

# Loop through the list
for i, df_i in enumerate(dfs, start=1):  # start=1 so i matches constituency number
    print(f"Total of {df_i.shape[0]} candidates participated in Constituency {i}")
# Out:
# Total of 32 candidates participated in Constituency 1
# Total of 30 candidates participated in Constituency 2
# Total of 23 candidates participated in Constituency 3
# Total of 31 candidates participated in Constituency 4
# Total of 29 candidates participated in Constituency 5
# Total of 24 candidates participated in Constituency 6
# Total of 29 candidates participated in Constituency 7
# Total of 19 candidates participated in Constituency 8
# Total of 22 candidates participated in Constituency 9
# Total of 18 candidates participated in Constituency 10
